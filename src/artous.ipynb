# %%
import pandas as pd

df_artous = pd.read_csv("artous.csv")

df_artous
# Out:
#      Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0             0         0.698   0.657    6    -7.405     0       0.5160
# 1             1         0.669   0.449    0    -7.658     0       0.0489
# 2             2         0.616   0.832   10    -5.084     1       0.0455
# 3             3         0.577   0.731    7    -7.028     0       0.0313
# 4             4         0.794   0.687    7    -5.028     0       0.0746
# ..          ...           ...     ...  ...       ...   ...          ...
# 736          16         0.609   0.810    1    -4.192     0       0.2330
# 737          17         0.734   0.617    5    -8.709     0       0.2830
# 738          18         0.816   0.565    0    -8.198     1       0.2730
# 739          19         0.825   0.761    8    -5.389     1       0.1040
# 740           0         0.818   0.683    8    -6.389     1       0.3880
#
#      acousticness  instrumentalness  liveness  ...            type  \
# 0         0.28400          0.000075    0.1240  ...  audio_features
# 1         0.18400          0.000000    0.0729  ...  audio_features
# 2         0.00542          0.939000    0.3600  ...  audio_features
# 3         0.23800          0.884000    0.2880  ...  audio_features
# 4         0.03950          0.400000    0.1150  ...  audio_features
# ..            ...               ...       ...  ...             ...
# 736       0.01800          0.008060    0.0420  ...  audio_features
# 737       0.19900          0.000002    0.0571  ...  audio_features
# 738       0.10400          0.000097    0.3030  ...  audio_features
# 739       0.01110          0.003590    0.3340  ...  audio_features
# 740       0.31300          0.000000    0.1040  ...  audio_features
#
#                          id                                   uri  \
# 0    3HgUXdJnCIL9duvpiSuB41  spotify:track:3HgUXdJnCIL9duvpiSuB41
# 1    65uoaqX5qcjXZRheAj1qQT  spotify:track:65uoaqX5qcjXZRheAj1qQT
# 2    6KCJB87jeBaJISz4STkwHe  spotify:track:6KCJB87jeBaJISz4STkwHe
# 3    4r0mdBEiLjPOBMLtNBMVgx  spotify:track:4r0mdBEiLjPOBMLtNBMVgx
# 4    0YV1vuvUaDye3prszC67BG  spotify:track:0YV1vuvUaDye3prszC67BG
# ..                      ...                                   ...
# 736  5THpk08EHh6d0sxhBYN4A2  spotify:track:5THpk08EHh6d0sxhBYN4A2
# 737  2NOWrWd5LJ54lEEjUsDAYH  spotify:track:2NOWrWd5LJ54lEEjUsDAYH
# 738  5tpmHdNIFWlaQjAKPvFwrk  spotify:track:5tpmHdNIFWlaQjAKPvFwrk
# 739  5o7ZDvfOry1MNhNLBOJulo  spotify:track:5o7ZDvfOry1MNhNLBOJulo
# 740  65WFyKVxDb6cYp33seCdwi  spotify:track:65WFyKVxDb6cYp33seCdwi
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/3HgUXdJnCIL9...
# 1    https://api.spotify.com/v1/tracks/65uoaqX5qcjX...
# 2    https://api.spotify.com/v1/tracks/6KCJB87jeBaJ...
# 3    https://api.spotify.com/v1/tracks/4r0mdBEiLjPO...
# 4    https://api.spotify.com/v1/tracks/0YV1vuvUaDye...
# ..                                                 ...
# 736  https://api.spotify.com/v1/tracks/5THpk08EHh6d...
# 737  https://api.spotify.com/v1/tracks/2NOWrWd5LJ54...
# 738  https://api.spotify.com/v1/tracks/5tpmHdNIFWla...
# 739  https://api.spotify.com/v1/tracks/5o7ZDvfOry1M...
# 740  https://api.spotify.com/v1/tracks/65WFyKVxDb6c...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/3HgU...      252254
# 1    https://api.spotify.com/v1/audio-analysis/65uo...      213493
# 2    https://api.spotify.com/v1/audio-analysis/6KCJ...      237440
# 3    https://api.spotify.com/v1/audio-analysis/4r0m...      256809
# 4    https://api.spotify.com/v1/audio-analysis/0YV1...      255984
# ..                                                 ...         ...
# 736  https://api.spotify.com/v1/audio-analysis/5THp...      264157
# 737  https://api.spotify.com/v1/audio-analysis/2NOW...      207987
# 738  https://api.spotify.com/v1/audio-analysis/5tpm...      186449
# 739  https://api.spotify.com/v1/audio-analysis/5o7Z...      163371
# 740  https://api.spotify.com/v1/audio-analysis/65WF...      181613
#
#     time_signature              added_at        song_title  \
# 0                4  2020-04-14T19:20:43Z         History X
# 1                4  2020-04-08T22:43:13Z    Dernière danse
# 2                4  2020-04-08T09:42:25Z            Shempi
# 3                4  2020-04-08T07:41:15Z          Abrasive
# 4                4  2020-04-08T07:35:06Z   Cream on Chrome
# ..             ...                   ...               ...
# 736              4  2019-01-02T06:22:02Z              Rush
# 737              4  2018-12-31T22:36:58Z             Liars
# 738              4  2018-12-31T22:33:08Z  The Real Godstep
# 739              4  2018-12-24T00:31:41Z       1000 Rounds
# 740              4  2018-12-23T21:57:33Z           Par ici
#
#                                      artists
# 0                                     Guizmo
# 1                                     Indila
# 2                                    Ratatat
# 3                                    Ratatat
# 4                                    Ratatat
# ..                                       ...
# 736                              Blooom,Kaii
# 737     Atili Bandalero,Baby Boom,Greencross
# 738  Atili Bandalero,Joseph Cotton,Biga Ranx
# 739                         Pouya,Ghostemane
# 740                                    Siboy
#
# [741 rows x 22 columns]

# %%
interestingColumns = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'valence', 'added_at']
df_saved_tracks_timeIndex = df_artous

df_saved_tracks_timeIndex.added_at = pd.to_datetime(df_saved_tracks_timeIndex.added_at)
df_saved_tracks_timeIndex.set_index(df_saved_tracks_timeIndex.added_at)
df_saved_tracks_timeIndex = df_saved_tracks_timeIndex[interestingColumns]
df_saved_tracks_timeIndex.index = df_saved_tracks_timeIndex.added_at
df_saved_tracks_timeIndex
# Out:
#                            danceability  energy  speechiness  acousticness  \
# added_at
# 2020-04-14 19:20:43+00:00         0.698   0.657       0.5160       0.28400
# 2020-04-08 22:43:13+00:00         0.669   0.449       0.0489       0.18400
# 2020-04-08 09:42:25+00:00         0.616   0.832       0.0455       0.00542
# 2020-04-08 07:41:15+00:00         0.577   0.731       0.0313       0.23800
# 2020-04-08 07:35:06+00:00         0.794   0.687       0.0746       0.03950
# ...                                 ...     ...          ...           ...
# 2019-01-02 06:22:02+00:00         0.609   0.810       0.2330       0.01800
# 2018-12-31 22:36:58+00:00         0.734   0.617       0.2830       0.19900
# 2018-12-31 22:33:08+00:00         0.816   0.565       0.2730       0.10400
# 2018-12-24 00:31:41+00:00         0.825   0.761       0.1040       0.01110
# 2018-12-23 21:57:33+00:00         0.818   0.683       0.3880       0.31300
#
#                            instrumentalness  valence                  added_at
# added_at
# 2020-04-14 19:20:43+00:00          0.000075    0.257 2020-04-14 19:20:43+00:00
# 2020-04-08 22:43:13+00:00          0.000000    0.327 2020-04-08 22:43:13+00:00
# 2020-04-08 09:42:25+00:00          0.939000    0.492 2020-04-08 09:42:25+00:00
# 2020-04-08 07:41:15+00:00          0.884000    0.308 2020-04-08 07:41:15+00:00
# 2020-04-08 07:35:06+00:00          0.400000    0.787 2020-04-08 07:35:06+00:00
# ...                                     ...      ...                       ...
# 2019-01-02 06:22:02+00:00          0.008060    0.573 2019-01-02 06:22:02+00:00
# 2018-12-31 22:36:58+00:00          0.000002    0.768 2018-12-31 22:36:58+00:00
# 2018-12-31 22:33:08+00:00          0.000097    0.774 2018-12-31 22:33:08+00:00
# 2018-12-24 00:31:41+00:00          0.003590    0.161 2018-12-24 00:31:41+00:00
# 2018-12-23 21:57:33+00:00          0.000000    0.553 2018-12-23 21:57:33+00:00
#
# [741 rows x 7 columns]

# %%
import seaborn as sns

testColumn = ['danceability']
sns.set(rc={'figure.figsize':(20, 10)})
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["energy"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["speechiness"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["acousticness"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["acousticness"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["instrumentalness"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumn = ["valence"]
df_saved_tracks_timeIndex[testColumn].plot(marker='.', alpha=0.8)

# %%
testColumns = ['danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'valence']
df_saved_tracks_timeIndex[testColumns].plot(marker='.', alpha=0.5)
